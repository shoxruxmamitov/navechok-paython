# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/navechok-paython/blob/main/chiziqli_algebrA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# chiziqli algebra

# %%
import numpy as np

# %%
orderblok = np.array([[10., 11., 12., 13.], [14., 15., 16., 17.]])

# %%
orderblok # 2 va 4 qatorli massiv tuzdik
# Out:
# array([[10., 11., 12., 13.],
#        [14., 15., 16., 17.]])

# %%
klassik = np.array([[18, 19, 20, 21], [22, 23, 24, 25,]])

# %%
klassik # 2 va 4 qatorli massiv tuzdik
# Out:
# array([[18, 19, 20, 21],
#        [22, 23, 24, 25]])

# %%
orderblok + klassik # 2 ta massivni qoshadi
# Out:
# array([[28., 30., 32., 34.],
#        [36., 38., 40., 42.]])

# %%
orderblok*3 # orderblok massivni har bitta elementini 3 ka kopatirib beradi
# Out:
# array([[30., 33., 36., 39.],
#        [42., 45., 48., 51.]])

# %%
klassik * orderblok
# Out:
# array([[180., 209., 240., 273.],
#        [308., 345., 384., 425.]])
