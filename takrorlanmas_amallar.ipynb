# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/navechok-paython/blob/main/takrorlanmas_amallar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Massivga yo'naltirilgan dasturlash

# %%
import numpy as np

# %% [markdown]
# massiv yaratib olamiz

# %%
ism = np.array(['Shoxrux', 'Olim', 'Javohir', 'Shoxrux', 'Sulton', 'Olim'])
malumot = np.array([1, 1, 1, 5, 5, 6, 6, 2, 2])

# %% [markdown]
# unique

# %%
np.unique(ism) #ism dagi elemenlarni bir xill elementlarni olib tashlab faqat bittasni chiqaradi
# Out:
# array(['Javohir', 'Olim', 'Shoxrux', 'Sulton'], dtype='<U7')

# %%
set(ism) #ism dagi elementlarni chiqarib beradi
# Out:
# {np.str_('Javohir'), np.str_('Olim'), np.str_('Shoxrux'), np.str_('Sulton')}

# %%
set(malumot)
# Out:
# {np.int64(1), np.int64(2), np.int64(5), np.int64(6)}

# %% [markdown]
# isin

# %%
kent1 = np.array([12, 21, 31, 32, 30, 20, 10])
kent2 = np.array([8, 12, 30, 51, 10])

# %%
np.isin(kent1 , kent2) # kent1 va kent2 ozgaruvchining funksialarida bir xil elemnt borligini tekshiradi
# Out:
# array([ True, False, False, False,  True, False,  True])

# %% [markdown]
# setdiff1d

# %%
sinfdosh = np.array(['Dior', 'Sunnat', 'Hasan', 'Samir', 'Umid', 'Inom'])
kursdosh = np.array(['Sunnat', 'Bilolidin', 'Samir', 'Hursand', 'Inom', 'Farrux'])

# %%
np.setdiff1d(sinfdosh, kursdosh) # bu kodimiz orqali 2 ta elemtni bir biriga oxshagan elemntni olib tashlab
# Out:
# array(['Dior', 'Hasan', 'Umid'], dtype='<U6')

# %% [markdown]
# Amaliot uchun

# %%
kvv_tolanmagan = np.array(['Javoxir', 'Shoxrux', 'Islom', 'Shaxrior', 'Muhammad', 'Siroj'])
kvv_tolangan = np.array(['Shoxrux', 'Javoxir', 'Siroj'])

# %%
np.setdiff1d(kvv_tolanmagan, kvv_tolangan) # kvv pulini tolaganlarni chiqarib tolamaganlarni bizga chiqarib berdi
# Out:
# array(['Islom', 'Muhammad', 'Shaxrior'], dtype='<U8')

# %%
filial = np.array(['iqtisod', 'suni intelekt', 'injener', 'iqtisod', 'oqituvchi', 'injener', 'axborot texnologia', 'molia', 'menejr', 'suni intelekt', 'molia', 'oqituvchi'])

# %%
np.unique(filial) # funkialar ichidan bir xillarini faqat bittasini chiqarib berdi
# Out:
# array(['axborot texnologia', 'injener', 'iqtisod', 'menejr', 'molia',
#        'oqituvchi', 'suni intelekt'], dtype='<U18')
